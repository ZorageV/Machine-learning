# %%
a_number = 34
if (a_number % 2 == 0):
    print('even')
# Out:
# even

# %%
a_number = 11
if (a_number % 2 != 0):
    print('odd')
# Out:
# odd

# %%
a_number = 34
if (a_number // 3 == 11):
    print('floor division')
else:
    print('no')
# Out:
# floor division

# %%
the_3_musketeers = ('man', 'jeet', 'singh')
if( 'man' in the_3_musketeers):
    print('yes')
else:
    print('no')
# Out:
# yes

# %% [markdown]
# NON - boolean conditions such empty strings,lists,tuples,sets,dictionary's

# %%
if '':
    print('empty string hasn\'t been taken as none by boolean fucntion')
else:
    print('value taken as none')
# Out:
# value taken as none

# %%
i = 1
result = 1
while(i<=5):
    result = i * result
    i += 1
print('the factorail of 5 is {}'.format(result))
# Out:
# the factorail of 5 is 120
